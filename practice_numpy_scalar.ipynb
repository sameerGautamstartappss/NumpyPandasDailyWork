# %%
import numpy as np

# %%
python_list = (lambda num : list(int(input(f"Enter the {i+1} element in the list : ")) for i in range(num)))(int(input("Enter the number of elements in the list : ")))
# Out:
# Enter the number of elements in the list :  3
# Enter the 1 element in the list :  2
# Enter the 2 element in the list :  3
# Enter the 3 element in the list :  5

# %%
python_list
# Out:
# [2, 3, 5]

# %%
numpy_array = np.array(python_list)

# %%
numpy_array
# Out:
# array([2, 3, 5])

# %%
numpy_array.shape
# Out:
# (3,)
